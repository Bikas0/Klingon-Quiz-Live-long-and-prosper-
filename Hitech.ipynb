# %% [markdown]
# # Version 1: Things are only impossible until they’re not

# %%
with open("klingon-english.txt") as f:
    contents = f.read()
    
x = contents.split("\n")
data = [i.split('|') for i in x]
klin_w = []
eng_w = []
for i in range (len(data)-1):
    klin_w.append(data[i][0])
    eng_w.append(data[i][1])
    
user_input = input("Take input into the computer :  ")

if user_input in eng_w:
    index = -1
    for i in range(len(eng_w)):
        if user_input == eng_w[i]:
            index = i 
            user_input = klin_w[index]

if user_input in klin_w:
    print("Correct!")
    
else:
    output = "impossible cause initial letter doesn't match"
    for i in range(len(klin_w)):
        if (user_input[0].lower() == klin_w[i][0]) or (user_input[0].upper() == klin_w[i][0]): 
            output = klin_w[i]        
    print(f"Sorry, you're wrong!\nThe correct answer is {output}")

# %% [markdown]
# # Version 2: Without freedom of choice there is no creativity

# %%
    
with open("klingon-english.txt") as f:
    contents = f.read()
    
x = contents.split("\n")
data = [i.split('|') for i in x]
klin_w = []
eng_w = []

for i in range (len(data)-1):
    klin_w.append(data[i][0])
    eng_w.append(data[i][1])
    
vowel = ["a","e","i","o","u"]
consonant = []  


def remove_dup(a):
    i = 0
    while i < len(a):
        j = i+1
        
        while j<len(a):
            if (a[i][0] == a[j]):
                del a[j]
            else:
                j += 1
        i += 1        

vowel = ["a","e","i","o","u"]
constant = []

i = 0
while i < (len(klin_w)):
    letter = klin_w[i][0]
    if (letter not in vowel and klin_w[i][1] == "h"):
        consonant.append(klin_w[i][0:2])    
    if(letter not in vowel):
         consonant.append(klin_w[i][0])
            
    i += 1
  
    
remove_dup(consonant)  
        
print(consonant) 


user_input = input()
while (user_input not in consonant):
    print("Please enter a valid klingon constant")
    user_input = input()
    if (user_input in consonant):
        chosen_word = input("Find a Klingon word that starts with the chosen consonant : ")
        break

j = 0       
while j < (len(klin_w)):
    if chosen_word in klin_w:
        print("Correct!")
        break
    
    else:
        output = "impossible cause initial letter doesn't match"
        k = 0
        while k < len(klin_w):
            if (chosen_word[0] == klin_w[k][0]): 
                output = klin_w[k] 
                break
            k += 1    
        print(f"Sorry, you're wrong!\nThe correct answer is {output}")   
        break

    j += 1

# %% [markdown]
# # Version 3: Logic is the beginning of wisdom, not the end

# %%
    
with open("klingon-english.txt") as f:
    contents = f.read()
    
x = contents.split("\n")
data = [i.split('|') for i in x]
klin_w = []
eng_w = []

for i in range (len(data)-1):
    klin_w.append(data[i][0])
    eng_w.append(data[i][1])
    



def remove_dup(a):
    i = 0
    while i < len(a):
        j = i+1
        
        while j<len(a):
            if (a[i][0] == a[j]):
                del a[j]
            else:
                j += 1
        i += 1        

        
vowel = ["a","e","i","o","u"]
consonant = []  
i = 0
while i < (len(klin_w)):
    letter = klin_w[i][0]
    if (letter not in vowel and klin_w[i][1] == "h"):
        consonant.append(klin_w[i][0:2])    
    if(letter not in vowel):
         consonant.append(klin_w[i][0])
            
    i += 1
  
    
remove_dup(consonant)  
        
##########################

user_input = input()
if (user_input in consonant):
    chosen_word = input("Find a Klingon word that starts with the chosen consonant : ")
        
while (user_input not in consonant):
    print("Please enter a valid klingon constant")
    user_input = input()
    if (user_input in consonant):
        chosen_word = input("Find a Klingon word that starts with the chosen consonant : ")
        break
###########################
j = 0       
while j < (len(klin_w)):
    if chosen_word in klin_w:
        print("Correct!")
        break
    
    else:
        print(f"Sorry, you're wrong!")
        
        hint_value = ""

        i = 0
        while i < len(klin_w):
            if(chosen_word[0] == klin_w[i][0]):
                index_value = klin_w[i]
                hint = 0
                while hint < (len(index_value)):
                    if(hint == 0):
                        hint_value += str(index_value[0])
                    elif(hint == (len(index_value)-1)):
                        hint_value += str(index_value[-1])
                    else:
                        hint_value += str("*")
                    hint += 1
                print(hint_value)     
            i += 1  
                   
                
        output = "impossible cause initial letter doesn't match"
        
        k = 0
        while k < len(klin_w):
            if (chosen_word[0] == klin_w[k][0]): 
                output = klin_w[k] 
                break
            k += 1    
        print(f"The correct answer is {output}")   
        break

    j += 1

# %%
    
with open("klingon-english.txt") as f:
    contents = f.read()
    
x = contents.split("\n")
data = [i.split('|') for i in x]
klin_w = []
eng_w = []

for i in range (len(data)-1):
    klin_w.append(data[i][0])
    eng_w.append(data[i][1])
    



def remove_dup(a):
    i = 0
    while i < len(a):
        j = i+1
        
        while j<len(a):
            if (a[i][0] == a[j]):
                del a[j]
            else:
                j += 1
        i += 1        

        
vowel = ["a","e","i","o","u"]
consonant = []  
i = 0
while i < (len(klin_w)):
    letter = klin_w[i][0]
    if (letter not in vowel and klin_w[i][1] == "h"):
        consonant.append(klin_w[i][0:2])    
    if(letter not in vowel):
         consonant.append(klin_w[i][0])
            
    i += 1
  
    
remove_dup(consonant)  
        
##########################

user_input = input()
if (user_input in consonant):
    print("How do you translate be evil to klingon? You have 3 attempts left.")
    chosen_word = input("")
        
while (user_input not in consonant):
    print("Please enter a valid klingon constant")
    user_input = input()
    if (user_input in consonant):
        print("How do you translate be evil to klingon? You have 3 attempts left.")
        chosen_word = input("")
        break
###########################
j = 0       
while j < (len(klin_w)):
    if chosen_word in klin_w:
        print("Correct!")
        break
    
    else:
        
        count = 0
        attempt = 2
        while count < 2:
            print(f"Sorry, you're wrong!")
            print(f"How do you translate be evil to klingon? You have {attempt} attempts left.")
            attempt -= 1
            if chosen_word in klin_w:
                print("Correct!")
                break
            else:
                hint_value = ""
                i = 0
                while i < len(klin_w):
                    if(chosen_word[0] == klin_w[i][0]):
                        index_value = klin_w[i]
                        hint = 0
                        while (hint < (len(index_value))):
                            if(hint == 0):
                                hint_value += str(index_value[0])
                            elif(hint == (len(index_value)-1)):
                                hint_value += str(index_value[-1])
                            else:
                                hint_value += str("*")
                            hint += 1
                        print(f"Hint: {hint_value}")
                    i += 1 
                    
                    
            chosen_word = input("")        
            count += 1
        
        if chosen_word in klin_w:
            print("Correct!")
            break        
        
        else:
            
            output = "impossible cause initial letter doesn't match"
        
            k = 0
            while k < len(klin_w):
                if (chosen_word[0] == klin_w[k][0]): 
                    output = klin_w[k] 
                    break
                k += 1    
            print(f"Sorry, you're wrong!\nThe correct answer is {output}")   
            break

    j += 1
# Out:
# bdbd
# Please enter a valid klingon constant
# bdfbg
# Please enter a valid klingon constant
# b
# How do you translate be evil to klingon? You have 3 attempts left.
# bfg
# Sorry, you're wrong!
# How do you translate be evil to klingon? You have 2 attempts left.
# Hint: b***h
# bsfgb
# Sorry, you're wrong!
# How do you translate be evil to klingon? You have 1 attempts left.
# Hint: b***h
# bfgb
# Sorry, you're wrong!
# The correct answer is batlh

# %% [markdown]
# # Klingon Quiz Problem Version 4: Live long and prosper!

# %%
    
with open("klingon-english.txt") as f:
    contents = f.read()
    
x = contents.split("\n")
data = [i.split('|') for i in x]
klin_w = []
eng_w = []

for i in range (len(data)-1):
    klin_w.append(data[i][0])
    eng_w.append(data[i][1])
    



def remove_dup(a):
    i = 0
    while i < len(a):
        j = i+1
        
        while j<len(a):
            if (a[i][0] == a[j]):
                del a[j]
            else:
                j += 1
        i += 1        

        
vowel = ["a","e","i","o","u"]
consonant = []  
i = 0
while i < (len(klin_w)):
    letter = klin_w[i][0]
    if (letter not in vowel and klin_w[i][1] == "h"):
        consonant.append(klin_w[i][0:2])    
    if(letter not in vowel):
         consonant.append(klin_w[i][0])
            
    i += 1
  
    
remove_dup(consonant)  
        
##########################

user_input = input("")
if (user_input in consonant):
    print("How do you translate be evil to klingon? You have 3 attempts left.")
    chosen_word = input("")
        
while (user_input not in consonant):
    print("Please enter a valid klingon constant")
    user_input = input("")
    if (user_input in consonant):
        print("How do you translate be evil to klingon? You have 3 attempts left.")
        chosen_word = input("")
        break
###########################
j = 0       
while j < (len(klin_w)):
    if chosen_word in klin_w:
        print("Correct!")
        break
    
    else:
        
        count = 0
        attempt = 2
        while count < 2:
            print(f"Sorry, you're wrong!")
            print(f"How do you translate be evil to klingon? You have {attempt} attempts left.")
            attempt -= 1
            if chosen_word in klin_w:
                print("Correct!")
                break
            else:
                hint_value = ""
                i = 0
                while i < len(klin_w):
                    if(chosen_word[0] == klin_w[i][0]):
                        index_value = klin_w[i]
                        if(count == 0):
                            hint = 0
                            while (hint < (len(index_value))):
                                if(hint == 0):
                                    hint_value += str(index_value[0])
                                elif(hint == (len(index_value)-1)):
                                    hint_value += str(index_value[-1])
                                else:
                                    hint_value += str("*")
                                hint += 1
                        else:
                            hint = 0
                            while (hint < (len(index_value))):
                                if(hint == 0):
                                    hint_value += str(index_value[0])
                                elif(hint == 1):
                                    hint_value += str(index_value[1])
                                elif(hint == (len(index_value)-1)):
                                    hint_value += str(index_value[-1])
                                else:
                                    hint_value += str("*")
                                hint += 1
                        
                        print(f"Hint: {hint_value}")
                    i += 1 
                    
            chosen_word = input("")
                    
            count += 1
        
                   
        if chosen_word in klin_w:
            print("Correct!")
            break
            
        else:
            output = "impossible cause initial letter doesn't match"
        
            k = 0
            while k < len(klin_w):
                if (chosen_word[0] == klin_w[k][0]): 
                    output = klin_w[k] 
                    break
                k += 1    
            print(f"Sorry, you're wrong!\nThe correct answer is {output}")   
            break
    j += 1
# Out:
# b
# How do you translate be evil to klingon? You have 3 attempts left.
# bbr
# Sorry, you're wrong!
# How do you translate be evil to klingon? You have 2 attempts left.
# Hint: b***h
# btgtg
# Sorry, you're wrong!
# How do you translate be evil to klingon? You have 1 attempts left.
# Hint: ba**h
# batlh
# Correct!
